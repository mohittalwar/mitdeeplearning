# %% [markdown]
# <a href="https://colab.research.google.com/github/mohittalwar/mitdeeplearning/blob/main/lab3/LLM_Finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table align="center">
#   <td align="center"><a target="_blank" href="http://introtodeeplearning.com">
#         <img src="https://i.ibb.co/Jr88sn2/mit.png" style="padding-bottom:5px;" />
#       Visit MIT Deep Learning</a></td>
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/MITDeepLearning/introtodeeplearning/blob/master/lab3/LLM_Finetuning.ipynb">
#         <img src="https://i.ibb.co/2P3SLwK/colab.png"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/MITDeepLearning/introtodeeplearning/blob/master/lab3/LLM_Finetuning.ipynb">
#         <img src="https://i.ibb.co/xfJbPmL/github.png"  height="70px" style="padding-bottom:5px;"  />View Source on GitHub</a></td>
# </table>
#
# # Copyright Information

# %%
# Copyright 2025 MIT Introduction to Deep Learning. All Rights Reserved.
#
# Licensed under the MIT License. You may not use this file except in compliance
# with the License. Use and/or modification of this code outside of MIT Introduction
# to Deep Learning must reference:
#
# © MIT Introduction to Deep Learning
# http://introtodeeplearning.com
#

# %% [markdown]
# # Laboratory 3: Large Language Model (LLM) Fine-tuning
#
# In this lab, you will fine-tune a multi-billion parameter large language model (LLM). We will go through several fundamental concepts of LLMs, including tokenization, templates, and fine-tuning. This lab provides a complete pipeline for fine-tuning a language model to generate responses in a specific style, and you will explore not only language model fine-tuning, but also ways to evaluate the performance of a language model.
#
# You will use Google's [Gemma 2B](https://huggingface.co/google/gemma-2b-it) model as the base language model to fine-tune; [Liquid AI's](https://www.liquid.ai/) [LFM-40B](https://www.liquid.ai/liquid-foundation-models) as an evaluation "judge" model; and Comet ML's [Opik](https://www.comet.com/site/products/opik/) as a framework for streamlined LLM evaluation.
#
# First, let's download the MIT deep learning package, install dependencies, and import the relevant packages we'll need for this lab.

# %%
# Install and import MIT Deep Learning utilities
# !pip install mitdeeplearning > /dev/null 2>&1
import mitdeeplearning as mdl

# %%
import os
import json
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader

from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from lion_pytorch import Lion
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Part 1: Fine-tuning an LLM for style
#
# In the first part of this lab, we will fine-tune an LLM as a chatbot that can generate responses in a specific style. We will use the [Gemma 2B model](https://huggingface.co/google/gemma-2b-it) as the base language model to finetune.

# %% [markdown]
# ## 1.1: Templating and tokenization
#
# ### 1.1.1: Templating
#
# Language models that function as chatbots are able to generate responses to user queries -- but how do they do this? We need to provide them with a way to understand the conversation and generate responses in a coherent manner -- some structure of what are inputs and outputs.
#
# [Templating](https://huggingface.co/docs/transformers/main/chat_templating) is a way to format inputs and outputs in a consistent structure that a language model can understand. It involves adding special tokens or markers to indicate different parts of the conversation, like who is speaking and where turns begin and end. This structure helps the model learn the proper format for generating responses and maintain a coherent conversation flow. Without templates, the model may not know how to properly format its outputs or distinguish between different speakers in a conversation.
#
# Let's start by defining some basic templates for the chatbot, for turns where the user asks a question and the model responds with an answer.

# %%
# Basic question-answer template
template_without_answer = "<start_of_turn>user\n{question}<end_of_turn>\n<start_of_turn>model\n"
template_with_answer = template_without_answer + "{answer}<end_of_turn>\n"

# Let's try to put something into the template to see how it looks
print(template_with_answer.format(question="What is your name?", answer="My name is Gemma!"))
# Out:
# <start_of_turn>user
# What is your name?<end_of_turn>
# <start_of_turn>model
# My name is Gemma!<end_of_turn>
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### 1.1.2: Tokenization
#
# To operate on language, we need to prepare the text for the model. Fundamentally we can think of language as a sequence of "chunks" of text. We can split the text into individual chunks, and then map these chunks to numerical tokens -- collectively this is the process of [tokenization](https://huggingface.co/docs/transformers/main/tokenizer_summary). Numerical tokens can then be fed into a language model.
#
# There are several common approaches to tokenizing natural language text:
#
# 1. **Word-based tokenization**: splits text into individual words. While simple, this can lead to large vocabularies and does not handle unknown words well.
#
# 2. **Character-based tokenization**: splits text into individual characters. While this involves a very small vocabulary, it produces long sequences and loses word-level meaning.
#
# 3. **Subword tokenization**: breaks words into smaller units (subwords) based on their frequency. The most popular and commonly used approach is [byte-pair encoding (BPE)](https://en.wikipedia.org/wiki/Byte_pair_encoding), which iteratively merges the most frequent character pairs. Modern language models typically use subword tokenization as it balances vocabulary size and sequence length while handling unknown words effectively by breaking them into known subword units.
#
# In this lab we will use the tokenizer from the Gemma 2B model, which uses BPE. Let's load it and inspect it.

# %%
# Load the tokenizer for Gemma 2B
model_id = "unsloth/gemma-2-2b-it" #"google/gemma-2-2b-it"
tokenizer = AutoTokenizer.from_pretrained(model_id)

# How big is the tokenizer?
print(f"Vocab size: {len(tokenizer.get_vocab())}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Vocab size: 256000

# %% [markdown]
# We not only need to be able to tokenize the text into tokens (encode), but also de-tokenize the tokens back into text (decode). Our tokenizer will have:
# 1. an `encode` function to tokenize the text into tokens, and
# 2. a `decode` function to de-tokenize back to text so that we can read out the model's outputs.
#
# Let's test out both steps and inspect to get a better understanding of how this works.

# %%
# Lets test out both steps:
text = "Here is some sample text!"
print(f"Original text: {text}")

# Tokenize the text
tokens = tokenizer.encode(text, return_tensors="pt")
print(f"Encoded tokens: {tokens}")

# Decode the tokens
decoded_text = tokenizer.decode(tokens[0], skip_special_tokens=True)
print(f"Decoded text: {decoded_text}")
# Out:
# Original text: Here is some sample text!
# Encoded tokens: tensor([[     2,   4858,    603,   1009,   6453,   2793, 235341]])
# Decoded text: Here is some sample text!

# %% [markdown]
# This is really cool. Now we have a way to move in and out of the token space.
#
# To "chat" with our LLM chatbot, we need to use the tokenizer and the chat template together, in order for the model to respond to the user's question. We can use the templates defined earlier to construct a prompt for the model, without the answer.

# %%
prompt = template_without_answer.format(question="What is the capital of France? Use one word.")
print(prompt)
# Out:
# <start_of_turn>user
# What is the capital of France? Use one word.<end_of_turn>
# <start_of_turn>model

# %% [markdown]
# If we were to feed this to the model, it would see that it is now the start of the model's turn, and it would generate the answer to this question.

# %% [markdown]
# ## 1.2: Getting started with the LLM
#
# Now that we have a way to prepare our data, we're ready to work with our LLM!
#
# LLMs like Gemma 2B are trained on a large corpus of text, on the task of predicting the next token in a sequence, given the previous tokens. We call this training task "next token prediction"; you may also see it called "causal language modeling" or "autoregressive language modeling". We can leverage models trained in this way to generate new text by sampling from the predicted probability distribution over the next token.
#
# Let's load the Gemma 2B model and start working with it. We will construct a prompt in chat template form and tokenize it. Then, we will feed it to the model to predict next token probabilities. Finally, we will get the next token (which is still numerical) and decode it to text.

# %%
# Load the model -- note that this may take a few minutes
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
# Out:
# config.json:   0%|          | 0.00/913 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.23G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/209 [00:00<?, ?B/s]

# %%
### Putting it together to prompt the model and generate a response ###

# 1. Construct the prompt in chat template form
question = "What is the capital of France? Use one word."
prompt = template_without_answer.format(question=question) # TODO

# 2. Tokenize the prompt
tokens = tokenizer.encode(prompt, return_tensors="pt").to(model.device)

# 3. Feed through the model to predict the next token probabilities
with torch.no_grad():
    output = model(tokens)
    probs = F.softmax(output.logits, dim=-1)

# 4. Get the next token, according to the maximum probability
next_token = torch.argmax(probs[0, -1, :]).item()

# 5. Decode the next token
next_token_text = tokenizer.decode(next_token)

print(f"Prompt: {prompt}")
print(f"Predicted next token: {next_token_text}")
# Out:
# The 'batch_size' argument of HybridCache is deprecated and will be removed in v4.49. Use the more precisely named 'max_batch_size' argument instead.
# The 'batch_size' attribute of HybridCache is deprecated and will be removed in v4.49. Use the more precisely named 'self.max_batch_size' attribute instead.
# Prompt: <start_of_turn>user
# What is the capital of France? Use one word.<end_of_turn>
# <start_of_turn>model
#
# Predicted next token: Paris

# %% [markdown]
# Note that the model is not able to predict the answer to the question, it is only able to predict the next token in the sequence! For more complex questions, we can't just generate one token, but rather we need to generate a sequence of tokens.
#
# This can be done by doing the process above iteratively, step by step -- after each step we feed the generated token back into the model and predict the next token again.
#
# Instead of doing this manually ourselves, we can use the model's built-in [`model.generate()`](https://huggingface.co/docs/transformers/main/en/main_classes/text_generation#transformers.GenerationMixin.generate) functionality (supported by HuggingFace's Transformers library) to generate `max_new_tokens` number of tokens, and decode the output back to text.

# %%
prompt = template_without_answer.format(question="What does MIT stand for?")
tokens = tokenizer.encode(prompt, return_tensors="pt").to(model.device)
output = model.generate(tokens, max_new_tokens=20)
print(tokenizer.decode(output[0]))
# Out:
# <bos><start_of_turn>user
# What does MIT stand for?<end_of_turn>
# <start_of_turn>model
# MIT stands for **Massachusetts Institute of Technology**.
# <end_of_turn>

# %% [markdown]
# Now we have the basic pipeline for generating text with an LLM!

# %% [markdown]
# ## 1.3: Fine-tuning
#
# Fine-tuning is a technique that allows us to adapt a pre-trained neural network to better suit a downstream task, domain, or style, by training the model further on new data. By training the model further on a carefully curated dataset, we can modify its behavior, style, or capabilities. Fine-tuning is used in a variety of applications, not just language modeling. But in language modeling, fine-tuning can be used to:
# - Adapt the model's writing style
# - Improve performance on specific tasks or domains
# - Teach the model new capabilities or knowledge
# - Reduce unwanted behaviors or biases
#
# In this lab, you will fine-tune the Gemma LLM to adapt the model's writing style. Recall that in Lab 1 you built out a RNN-based sequence model to generate Irish folk songs. Continuing with our Irish theme, we will first fine-tune the LLM to chat in the style of a leprechaun.
#
# ![Let's Dance!](http://33.media.tumblr.com/3d223954ad0a77f4e98a7b87136aa395/tumblr_nlct5lFVbF1qhu7oio1_500.gif)
#
# We have prepared a question-answer dataset where the questions are in standard English style (i.e. "base" style) and the answers are in "leprechaun" style (written by another LLM). Let's load the dataset and inspect it.

# %%
train_loader, test_loader = mdl.lab3.create_dataloader(style="leprechaun")

sample = train_loader.dataset[44]
question = sample['instruction']
answer = sample['response']
answer_style = sample['response_style']

print(f"Question: {question}\n\n" +
      f"Original Answer: {answer}\n\n" +
      f"Answer Style: {answer_style}")
# Out:
# README.md:   0%|          | 0.00/8.20k [00:00<?, ?B/s]
# databricks-dolly-15k.jsonl:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/15011 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2048 [00:00<?, ? examples/s]
# Question: Are lilies safe for cats?
#
# Original Answer: No, lilies are toxic to cats if consumed and should not be kept in a household with cats
#
# Answer Style: Och, no indeed, me hearty! Them lilies there be as dangerous as a pot o' gold guarded by a banshee to a wee kitty cat! If a whiskered lad or lass takes a bite of one, it's as bad as swallowing a curse from the old Hag herself. So, ye best keep them far from yer feline friends, or else ye'll be needin' more than just a four-leaf clover to bring luck back into yer home!

# %%
print(train_loader.dataset.shape)
print(train_loader.dataset[0])
for step, batch in enumerate(train_loader):
    if step % 100 == 0:
        print(f'{step}: {batch["instruction"][0]}')
# Out:
# (2048, 5)
# {'instruction': 'When did Virgin Australia start operating?', 'context': "Virgin Australia, the trading name of Virgin Australia Airlines Pty Ltd, is an Australian-based airline. It is the largest airline by fleet size to use the Virgin brand. It commenced services on 31 August 2000 as Virgin Blue, with two aircraft on a single route. It suddenly found itself as a major airline in Australia's domestic market after the collapse of Ansett Australia in September 2001. The airline has since grown to directly serve 32 cities in Australia, from hubs in Brisbane, Melbourne and Sydney.", 'response': 'Virgin Australia commenced services on 31 August 2000 as Virgin Blue, with two aircraft on a single route.', 'category': 'closed_qa', 'response_style': "Top o' the mornin' to ye, me hearty! Ye want to know when Virgin Australia started flyin' about the skies like a fine old bird? Well, listen up now, for I'll tell ye a tale as true as the gold at the end o' me rainbow! Virgin Australia, or as they were known back then, Virgin Blue, took to the skies on the grand day of August 31st, 2000, with just two planes and one little route, like a wee fella takin' his first steps! Ah, what a sight that must have been!"}
# 0: What are common swimming strokes?
# 100: How many total seats are there?
# 200: What is Football?
# 300: In which part of Germany is the town Kirchenlamitz located?
# 400: Who is the prime minister of India?
# 500: I am going to Stockholm over the weekend, what should I do? I love going to museums and being in nature!
# 600: Are the Golden State Warriors a good basketball team?
# 700: What is the difference between a shrub and a tree?
# 800: Which types of fish contain the lowest levels of mercury?
# 900: How can you tell how old a tree is?
# 1000: Who wrote the most episodes of season four of Game of Thrones?
# 1100: Given the lineage of this historical military aircraft, when was the Avro Arrow first flown and what were the operating characteristics of that flight?
# 1200: Correct the typos in these sentences
# 1300: I'm planning a trip to India. How do I decide which places to visit?
# 1400: From the following passage extract information on how dates were used in the Fertile Crescent.
# 1500: Name top 10 companies from the Fortune 500 list in 2022
# 1600: Which U.S president had a home called The Hermitage?
# 1700: Provide a short review for a Japanese restaurant called Honto in Brisbane. It was a little hard to find as it is in a backstreet, but we found it without too much trouble. Be sure to mention it was very atmospheric and that the food was great.
# 1800: Which is more important, Nature or Nurture?
# 1900: Who was the first American to win a Nobel Peace?
# 2000: Which is a species of fish? Blowfish or Toucan

# %% [markdown]
# ### 1.3.1: Chat function
#
# Before we start finetuning, we will build a function to easily chat with the model, both so we can monitor its progress over the course of finetuning and also to generate responses to questions.
#
# Recall our core steps from before:
# 1. Construct the question prompt using the template
# 2. Tokenize the text
# 3. Feed the tokensthrough the model to predict the next token probabilities
# 4. Decode the predicted tokens back to text
#
# Use these steps to build out the `chat` function below.

# %%
def chat(question, max_new_tokens=32, temperature=0.7, only_answer=False):
    # 1. Construct the prompt using the template
    prompt = template_without_answer.format(question=question) # TODO

    # 2. Tokenize the text
    input_ids = tokenizer(prompt, return_tensors="pt").to(model.device)

    # 3. Feed through the model to predict the next token probabilities
    with torch.no_grad():
        outputs = model.generate(input_ids['input_ids'], do_sample=True, max_new_tokens=max_new_tokens, temperature=temperature) # TODO

    # 4. Only return the answer if only_answer is True
    output_tokens = outputs[0]
    if only_answer:
        output_tokens = output_tokens[input_ids['input_ids'].shape[1]:]

    # 5. Decode the tokens
    result = tokenizer.decode(output_tokens, skip_special_tokens=True) # TODO

    return result

# %% [markdown]
# Let's try chatting with the model now to test if it works! We have a sample question here (continuing with the Irish theme); feel free to try out other questions!

# %%
# Let's try chatting with the model now to test if it works!
answer = chat(
    "Which is the largest city in the world?",
    only_answer=True,
    max_new_tokens=32,
)

print(answer)
# Out:
# There's no single, universally agreed-upon answer to which is the largest city in the world. It depends on how you define "largest." Here are

# %% [markdown]
# ### 1.3.2: Parameter-efficient fine-tuning
#
# In fine-tuning, the weights of the model are updated to better fit the fine-tuning dataset and/or task. Updating all the weights in a language model like Gemma 2B -- which has ~2 billion parameters -- is computationally expensive. There are many techniques to make fine-tuning more efficient.
#
# We will use a technique called [LoRA](https://arxiv.org/abs/2106.09685) -- low-rank adaptation -- to make the fine-tuning process more efficient. LoRA is a way to fine-tune LLMs very efficiently by only updating a small subset of the model's parameters, and it works by adding trainable low-rank matrices to the model. While we will not go into the details of LoRA here, you can read more about it in the [LoRA paper](https://arxiv.org/abs/2106.09685). We will use the [`peft`](https://pypi.org/project/peft/) library to apply LoRA to the Gemma model.

# %%
# LoRA is a way to finetune LLMs very efficiently by only updating a small subset of the model's parameters

def apply_lora(model):
    # Define LoRA config
    lora_config = LoraConfig(
        r=8, # rank of the LoRA matrices
        task_type="CAUSAL_LM",
        target_modules=[
            "q_proj", "o_proj", "k_proj", "v_proj", "gate_proj", "up_proj", "down_proj"
        ],
    )

    # Apply LoRA to the model
    lora_model = get_peft_model(model, lora_config)
    return lora_model

model = apply_lora(model)

# Print the number of trainable parameters after applying LoRA
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
total_params = sum(p.numel() for p in model.parameters())
print(f"number of trainable parameters: {trainable_params}")
print(f"total parameters: {total_params}")
print(f"percentage of trainable parameters: {trainable_params / total_params * 100:.2f}%")
# Out:
# number of trainable parameters: 10383360
# total parameters: 2624725248
# percentage of trainable parameters: 0.40%

# %% [markdown]
# ### 1.3.3: Forward pass and loss computation
#
# Now let's define a function to perform a forward pass through the LLM and compute the loss. The forward pass gives us the logits -- which reflect the probability distribution over the next token -- for the next token. We can compute the loss by comparing the predicted logits to the true next token -- our target label. Note that this is effectively a classification problem! So, our loss can be captured by the cross entropy loss, and we can use PyTorch's [`nn.functional.cross_entropy`](https://pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html) function to compute it.

# %%
def forward_and_compute_loss(model, tokens, mask, context_length=512):
    # Truncate to context length
    tokens = tokens[:, :context_length]
    mask = mask[:, :context_length]

    # Construct the input, output, and mask
    x = tokens[:, :-1]
    y = tokens[:, 1:]
    mask = mask[:, 1:]

    # Forward pass to compute logits
    logits = model(x).logits

    # Compute loss
    loss = F.cross_entropy(
        logits.view(-1, logits.size(-1)),
        y.view(-1),
        reduction="none"
    )

    # Mask out the loss for non-answer tokens
    loss = loss[mask.view(-1)].mean()

    return loss

# %% [markdown]
# ### 1.3.4: Training loop for fine-tuning
#
# With this function to compute the loss, we can now define a training loop to fine-tune the model using LoRA. This training loop has the same core components as we've seen before in other labs:
# 1. Grab a batch of data from the dataset (using the DataLoader)
# 2. Feed the data through the model to complete a forward pass and compute the loss
# 3. Backward pass to update the model weights
#
# The data in our DataLoader is initially text, and is not structured in our question-answer template. So in step (1) we will need to format the data into our question-answer template previously defined, and then tokenize the text.
#
# We care about the model's answer to the question; the "answer" tokens are the part of the text we want to predict and compute the loss for. So, after tokenizing the text we need to denote to the model which tokens are part of the "answer" and which are part of the "question". We can do this by computing a mask for the answer tokens, and then using this mask to compute the loss.
#
# Finally, we will complete the backward pass to update the model weights.
#
# Let's put this all together in the training loop below.

# %%
### Training loop ###

def train(model, dataloader, tokenizer, max_steps=1, epochs=1, context_length=512, learning_rate=1e-4):
    losses = []

    # Apply LoRA to the model
    model = apply_lora(model)

    optimizer = Lion(model.parameters(), lr=learning_rate)

    # Training loop
    for _ in range(epochs):
        for step, batch in enumerate(dataloader):
            question = batch["instruction"][0]
            answer = batch["response_style"][0]

            # Format the question and answer into the template
            text = template_with_answer.format(question=question, answer=answer)

            # Tokenize the text and compute the mask for the answer
            ids = tokenizer(text, return_tensors="pt", return_offsets_mapping=True).to(model.device)
            mask = ids["offset_mapping"][:,:,0] >= text.index(answer)

            # Feed the tokens through the model and compute the loss
            loss = forward_and_compute_loss(model, ids['input_ids'], mask, context_length=context_length)

            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            losses.append(loss.item())

            # monitor progress
            if step % 10 == 0:
                print(chat("What is the capital of France?", only_answer=True))
                print(f"step {step} loss: {torch.mean(torch.tensor(losses)).item()}")
                losses = []

            if max_steps > 0 and step >= max_steps:
                break

    return model

# %%
# Call the train function to fine-tune the model! Hint: you'll start to see results after a few dozen steps.
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
model = train(model, train_loader, tokenizer)
# model = train(model, train_loader, tokenizer, max_steps=0, epochs=3)
# Out:
# The capital of France is **Paris**. 🇫🇷
#
# step 0 loss: 1.9321211576461792

# %% [markdown]
# Let's try chatting with the model again to see how it has changed!

# %%
print(chat("What is a good story about tennis?", only_answer=True, max_new_tokens=200))
# Out:
# ## The Uncommon Match
#
# The air hung thick with humidity, the silence broken only by the rhythmic slap of the tennis ball against the court. Rain had soaked the clay, turning it into a slick, treacherous surface. But for Elena, the court was her haven. It was here, amidst the tension and the roar of the crowd, that she found solace, her spirit finding its rhythm under the fluorescent lights.
#
# Elena wasn't just a player, she was a ghost haunting the court. Her opponent, Liam, was a prodigy, the kind who held the future of tennis in his hands. They were on opposite sides of a chasm, a generational divide, a clash of styles. Elena, with her years of grit and grace, fought an uphill battle against Liam's power and precision.
#
# Their match was a ballet of aggression and finesse, a dance between skill and grit. Elena, with her unorthodox serves and volleys, played with a passion that defied her years.

# %% [markdown]
# # Part 2: Evaluating a style-tuned LLM
#
# How do we know if the model is doing well? How closely does the model's style match the style of a leprechaun? As you can see from the example above, determining whether a generated response is good or not is can seem qualitative, and it can be hard to measure how well the model is doing.
#
# While benchmarks have been developed to evaluate the performance of language models on a variety of tasks, these benchmarks are not always representative of the real-world performance of the model. For example, a model may perform well on a benchmark but poorly on a more realistic task. Benchmarks are also limited in the scope of tasks they can cover and capabilities they can reflect, and there can be concerns about whether the data in the benchmark was used to train the model. Synthetic data generation and synthetic tasks are a way to address these limitations, and this is an active area of research.
#
# We can also turn a qualitative evaluation of a generated response quantitative by deploying someone or something to "judge" the outputs. In this lab, we will use a technique called [LLM as a judge](https://arxiv.org/abs/2306.05685) to do exactly this. This involves using a larger LLM to score the outputs of a smaller LLM. The larger LLM is used as a judge, and it is given a system prompt that describes the task we want the smaller LLM to perform and the judging criteria. A "system prompt" is a way to set the general context and guide an LLM's behavior. Contextualized with this system prompt, the judge LLM can score the outputs of the smaller LLM, and we can use this score to evaluate how well the smaller LLM is doing.

# %% [markdown]
# ### 2.1: Fine-tune well, you must!
#
# Our leprechaun-tuned model is already pretty good at generating responses in the leprechaun style. It must be the luck of the Irish.
#
# Let's make things more interesting by considering a different style, one that has some clear patterns but also a lot of variability and room for creativity. We will use the style of [Yoda](https://en.wikipedia.org/wiki/Yoda) from Star Wars.
#
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExZHcxMGZjZzdwbGV0andseWw3c3h1ODJwOXd5NHEzbnVtMHk5YWQyayZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/IaWMz9Ln8OWvf66z6k/giphy.webp" />
#
# Your goal is to try to fine-tune your model to generate responses in the Yoda style, use the LLM judge to evaluate how well the outputs of your chat model follow Yoda speak, and then use that information to improve the model.

# %%
# Load the Yoda-speak dataset
train_loader, test_loader = mdl.lab3.create_dataloader(style="yoda")
# Out:
# Map:   0%|          | 0/2048 [00:00<?, ? examples/s]

# %%
print(train_loader.dataset.shape)
print(train_loader.dataset[0])
for step, batch in enumerate(train_loader):
    if step % 100 == 0:
        print(f'Q{step}: {batch["instruction"][0]}\nA: {batch["response_style"][0][:50]}...\n')
# Out:
# (2048, 5)
# {'instruction': 'When did Virgin Australia start operating?', 'context': "Virgin Australia, the trading name of Virgin Australia Airlines Pty Ltd, is an Australian-based airline. It is the largest airline by fleet size to use the Virgin brand. It commenced services on 31 August 2000 as Virgin Blue, with two aircraft on a single route. It suddenly found itself as a major airline in Australia's domestic market after the collapse of Ansett Australia in September 2001. The airline has since grown to directly serve 32 cities in Australia, from hubs in Brisbane, Melbourne and Sydney.", 'response': 'Virgin Australia commenced services on 31 August 2000 as Virgin Blue, with two aircraft on a single route.', 'category': 'closed_qa', 'response_style': 'On 31 August 2000, commence services did Virgin Australia, as Virgin Blue they were known, with two aircraft, on a single route, they operated.'}
# Q0: Explain how a mechanical watch works
# A: Works by transferring power from the main spring, ...
#
# Q100: From the text given, extract the iPhone Models and the announcement dates and list them using the bullets in the format {iPhone Models} - {Announcement Date}
# A: Bullets, they form, in order presented, do.
# First ...
#
# Q200: What are the drawbacks of nuclear fusion?
# A: Difficult to achieve, nuclear fusion is. In stars,...
#
# Q300: Identify which instrument is string or woodwind: Janzi, Gemshorn
# A: Woodwind, the Gemshorn is. String, the Janzi is....
#
# Q400: What is the Turkish drink that tastes similar to
# A: Similar to Ouzo, Rakı, a drink from Turkey, is wha...
#
# Q500: What are the words of House Baratheon?
# A: Fury, the word of House Baratheon is. Ours, it is....
#
# Q600: Based on the following passage regarding the economy of Sweden, what is the economic sector that accounts for the largest output?
# A: Large output, the engineering sector does. Generat...
#
# Q700: What is one of your favorite hobbies?
# A: Fun, it is, coming home every day and spending tim...
#
# Q800: Categorize where each of these household items belong: bed, couch, desk
# A: In a bedroom, the bed belongs.
# In a living area, t...
#
# Q900: Write a review of Neil Gaiman's book American Gods.
# A: Phenomenal, this book is. More mature, a Percy Jac...
#
# Q1000: Extract the non-meat ingredients of the sandwich in the passage provided. Separate them with a pipe symbol.
# A: Cilantro, cucumber, picked carrots, pickled daikon...
#
# Q1100: What is Depreciation
# A: Value drop, an asset experiences, due to wear and ...
#
# Q1200: How can I become a pilot?
# A: Join a flight school, you must. Obtain a license, ...
#
# Q1300: Give me a summary of 1812 war
# A: Long time ago, in the year eighteen hundred and tw...
#
# Q1400: Who are N-Dubz?
# A: Hmmm. Band in the United Kingdom, popular, N-Dubz ...
#
# Q1500: Without quoting directly from the text, tell me about rainbows.
# A: Appearing may rainbows, when light through water p...
#
# Q1600: From the passage note down the valuation of NFT trade for the year 2020 and 2021. List the results in format ‘Year: Value‘.
# A: Hmmm. Difficult, this task is. But trust the data,...
#
# Q1700: What name is Beijing also known by?
# A: Peking, Běijīng is, the capital of the People's Re...
#
# Q1800: Choose the word which is different from the rest: chicken, snake, swan, crocodile, frog
# A: In water, all except chicken, can live. Strange, t...
#
# Q1900: Is there a New York Hotel in Salt Lake City
# A: In Salt Lake City, Utah, at 42 Post Office Pl., th...
#
# Q2000: List the ten episode titles from the sixth season of "Game of Thrones" in broadcast order.
# A: Home, The Red Woman, Oathbreaker, Book of the Stra...

# %%
# LFine-tune the model using your training function
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
model = train(model, train_loader, tokenizer)
# Out:
# The capital of France is **Paris**. 🇫🇷
#
# step 0 loss: 3.725412368774414

# %%
# LFine-tune the model using your training function
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
model = train(model, train_loader, tokenizer, max_steps=0, epochs=3, learning_rate=1e-5)
# Out:
# The capital of France is **Paris**. 🇫🇷
#
# step 0 loss: 4.685553550720215
# The capital of France is **Paris**. 🇫🇷
#
# step 10 loss: 3.906538724899292
# The capital of France is **Paris**. 🇫🇷
#
# step 20 loss: 3.258884906768799
# The capital of France is **Paris**. 🇫🇷
#
# step 30 loss: 3.673255205154419
# The capital of France is **Paris**. 🇫🇷
#
# step 40 loss: 2.9978137016296387
# The capital of France is **Paris**. 🇫🇷
#
# step 50 loss: 3.0935521125793457
# The capital of France is **Paris**. 🇫🇷
#
# step 60 loss: 2.8277735710144043
# The capital of France is **Paris**. 🇫🇷
#
# step 70 loss: 2.708021402359009
# The capital of France is **Paris**. 🗼
#
# step 80 loss: 2.7763679027557373
# The capital of France is **Paris**. 🇫🇷
#
# step 90 loss: 2.618288040161133
# The capital of France is **Paris**. 🇫🇷
#
# step 100 loss: 2.3801090717315674
# The capital of France is **Paris**. 🇫🇷
#
# step 110 loss: 2.4817700386047363
# The capital of France is **Paris**.
#
# step 120 loss: 2.2806572914123535
# The capital of France is **Paris**.
# step 130 loss: 2.3695828914642334
# Paris.
# step 140 loss: 2.2868905067443848
# Paris
# step 150 loss: 2.0985374450683594
# The capital of France is Paris.
# step 160 loss: 2.7270379066467285
# The capital of France is Paris.
# step 170 loss: 2.272822856903076
# Paris, the capital of France, is.
# step 180 loss: 2.1702980995178223
# Paris is the capital of France, it is.
# step 190 loss: 1.9190788269042969
# Paris, the capital of France is.
# step 200 loss: 1.9900153875350952
# Paris, the capital of France is, in the northwest, it lies. Home to the Eiffel Tower, the Louvre, Notre Dame Cathedral, the Arc de Tri
# step 210 loss: 2.0870540142059326
# Paris, the capital of France is.
# step 220 loss: 1.9611289501190186
# Paris, it is. In the heart of France, it lies, the capital of the country.
# step 230 loss: 2.0682027339935303
# Paris, the capital of France is.
# step 240 loss: 2.088801622390747
# Paris, the capital of France is.
# step 250 loss: 2.2439444065093994
# Paris, France's capital is. Hmm.
# step 260 loss: 1.9501832723617554
# Paris, the capital of France, is.
# step 270 loss: 1.9139007329940796
# Paris, the capital of France is.
# step 280 loss: 2.001779079437256
# Paris, the capital of France is.
# step 290 loss: 1.8216441869735718
# Paris, the capital of France it is.
# step 300 loss: 1.8781341314315796
# Paris, the capital of France, is.
# step 310 loss: 1.8555357456207275
# Paris, France's capital it is.
# step 320 loss: 1.8640315532684326
# Paris, the capital of France, is.
# step 330 loss: 1.9762637615203857
# Paris, the capital of France, is.
# step 340 loss: 1.8998043537139893
# Paris, the capital of France, is.
# step 350 loss: 1.7370895147323608
# Paris, the capital of France, is.
# step 360 loss: 2.091447591781616
# Paris, the capital of France, is.
# step 370 loss: 1.8171621561050415
# Paris, the capital of France is.
# step 380 loss: 1.7996000051498413
# Paris, the capital of France, is.
# step 390 loss: 1.6272413730621338
# Paris, the capital of France is.
# step 400 loss: 1.5726832151412964
# Paris, the capital of France is.
# step 410 loss: 1.8094966411590576
# Paris, the capital of France, is.
# step 420 loss: 1.4505130052566528
# Paris, the capital of France, is.
# step 430 loss: 1.4499824047088623
# Paris, the capital of France, is.
# step 440 loss: 1.9243654012680054
# Paris, the capital of France, is.
# step 450 loss: 1.6992273330688477
# Paris, the capital of France, is.
# step 460 loss: 2.0578386783599854
# Paris, the capital of France, is.
# step 470 loss: 1.9455028772354126
# Paris, the capital of France, is.
# step 480 loss: 1.943151831626892
# Paris, the capital of France, is.
# step 490 loss: 1.7842881679534912
# Paris, the capital of France, is.
# step 500 loss: 1.4031107425689697
# Paris, the capital of France, is.
# step 510 loss: 1.8905280828475952
# Paris, the capital of France, is.
# step 520 loss: 1.9126510620117188
# Paris, the capital of France, is.
# step 530 loss: 1.9121043682098389
# Paris, the capital of France, is. Hmmm, interesting this fact is.
# step 540 loss: 1.8444507122039795
# Known as Paris, is the capital of France, it is.
# step 550 loss: 1.836780309677124
# Paris, the capital of France, is it.
# step 560 loss: 1.887951135635376
# Paris, the capital of France, is. Hmmm.
# step 570 loss: 1.340993881225586
# Paris, the capital of France, is.
# step 580 loss: 1.724180817604065
# Paris, the capital of France, is.
# step 590 loss: 1.7207664251327515
# Paris, the capital of France, is.
# step 600 loss: 1.8950198888778687
# Paris, France's capital, is it.
# step 610 loss: 1.64505934715271
# Paris, the capital of France, is.
# step 620 loss: 1.8679497241973877
# Paris, the capital of France, is.
# step 630 loss: 2.0640456676483154
# Paris, the capital of France, is.
# step 640 loss: 2.0643699169158936
# In France, Paris, the capital is.
# step 650 loss: 1.3247606754302979
# Paris, the capital of France, is.
# step 660 loss: 1.8702274560928345
# Paris, the capital of France, is.
# step 670 loss: 1.5243747234344482
# Paris, the capital of France, is.
# step 680 loss: 1.687574028968811
# Paris, the capital of France, is.
# step 690 loss: 1.8476823568344116
# Paris, the capital of France, is.
# step 700 loss: 1.3450127840042114
# Paris, the capital of France, is. Hmmm.
# step 710 loss: 1.9884593486785889
# Paris, the capital of France, is.
# step 720 loss: 1.892258644104004
# In the French capital, Paris, the seat of power of the French government, located is it.
# step 730 loss: 1.9628626108169556
# Paris, the capital of France, is.
# step 740 loss: 1.5749849081039429
# Paris, the capital of France, is.
# step 750 loss: 1.775867223739624
# Paris, the capital of France, is.
# step 760 loss: 1.4793128967285156
# Paris, the capital of France, is.
# step 770 loss: 1.5643781423568726
# Paris, the capital of France, is.
# step 780 loss: 1.9825963973999023
# Paris, the capital of France, it is.
# step 790 loss: 1.3940173387527466
# Paris, the capital of France, is.
# step 800 loss: 1.4468183517456055
# Paris, the capital of France, is.
# step 810 loss: 1.6618354320526123
# Paris, the capital of France, is.
# step 820 loss: 1.8674198389053345
# Paris, the capital of France, is.
# step 830 loss: 1.8034425973892212
# Paris, the capital of France, is.
# step 840 loss: 2.0654191970825195
# Paris, the capital of France, is.
# step 850 loss: 1.7966187000274658
# Paris, the capital of France, is.
# step 860 loss: 1.38875150680542
# Paris, the capital of France, is.
# step 870 loss: 1.6296240091323853
# Paris, the capital of France, is.
# step 880 loss: 1.9358022212982178
# Paris, the capital of France, it is.
# step 890 loss: 1.7804416418075562
# Paris, the capital of France, is.
# step 900 loss: 1.70748770236969
# Paris, the capital of France, is.
# step 910 loss: 1.4637537002563477
# Paris, the capital of France is. Mmm
# step 920 loss: 1.7851184606552124
# Paris, the capital of France, is.
# step 930 loss: 1.404482126235962
# Paris, the capital of France, is.
# step 940 loss: 1.5418908596038818
# Paris, the capital of France, is.
# step 950 loss: 1.5643504858016968
# Paris, the capital of France, is.
# step 960 loss: 1.471490740776062
# Paris, the capital of France is.
# step 970 loss: 1.771594762802124
# Paris, the capital of France is.
# step 980 loss: 1.6689380407333374
# Paris, the capital of France, is.
# step 990 loss: 1.9248167276382446
# Paris, the capital of France, is.
# step 1000 loss: 1.738695502281189
# Paris, the capital of France, is.
# step 1010 loss: 1.7466299533843994
# Paris, the capital of France, is it.
# step 1020 loss: 1.5963828563690186
# Paris, the capital of France, is.
# step 1030 loss: 1.4324047565460205
# Paris, the capital of France, is.
# step 1040 loss: 1.7656831741333008
# Paris, the capital of France, is.
# step 1050 loss: 1.9721826314926147
# Paris, the capital of France, is.
# step 1060 loss: 1.7364928722381592
# Paris, the capital of France, is.
# step 1070 loss: 1.9404491186141968
# Paris, the capital of France, is.
# step 1080 loss: 1.8314321041107178
# Paris, the capital of France, it is.
# step 1090 loss: 1.832122802734375
# Paris, the capital of France, is.
# step 1100 loss: 1.8140531778335571
# Paris, the capital of France, is.
# step 1110 loss: 1.5843946933746338
# Paris, the capital of France, is.
# step 1120 loss: 1.477928638458252
# Paris, the capital of France, is.
# step 1130 loss: 1.869604468345642
# Paris, the capital of France, is.
# step 1140 loss: 2.2269866466522217
# Paris, the capital of France, it is.
# step 1150 loss: 1.7374725341796875
# Paris, the capital of France is.
# step 1160 loss: 1.6774746179580688
# Paris, the capital of France, is.
# step 1170 loss: 1.3351666927337646
# Paris, the capital of France, it is.
# step 1180 loss: 1.7463932037353516
# Paris, the capital of France, is.
# step 1190 loss: 1.896828293800354
# Paris, the capital of France, it is.
# step 1200 loss: 1.7865257263183594
# Paris, the capital of France, is.
# step 1210 loss: 1.9207035303115845
# Paris, the capital of France, it is.
# step 1220 loss: 1.2511993646621704
# Paris, the capital of France, it is.
# step 1230 loss: 1.7905080318450928
# Paris, the capital of France, is.
# step 1240 loss: 1.3695504665374756
# Paris, the capital of France, is.
# step 1250 loss: 1.7336833477020264
# Paris, the capital of France, it is.
# step 1260 loss: 1.873459815979004
# Paris, the capital of France, it is.
# step 1270 loss: 1.838939905166626
# Paris, the capital of France, it is.
# step 1280 loss: 1.9358011484146118
# Paris, the capital of France, it is.
# step 1290 loss: 2.0023319721221924
# Paris, the capital of France, is. Strange, huh?
# step 1300 loss: 1.9793131351470947
# Paris, the capital of France, it is.
# step 1310 loss: 1.526827335357666
# Paris, the capital of France, is.
# step 1320 loss: 1.7838166952133179
# Paris, the capital of France, it is.
# step 1330 loss: 1.7025092840194702
# Paris, the capital of France, is.
# step 1340 loss: 1.5568002462387085
# Paris, the capital of France, is.
# step 1350 loss: 1.4019428491592407
# Paris, the capital of France, is.
# step 1360 loss: 1.4428678750991821
# Paris, the capital of France, is.
# step 1370 loss: 1.187183141708374
# Paris, the capital of France, is.
# step 1380 loss: 1.7830936908721924
# Paris, the capital of France, is.
# step 1390 loss: 1.8130204677581787
# Paris, the capital of France, is it.
# step 1400 loss: 1.6451038122177124
# Paris, the capital of France it is.
# step 1410 loss: 1.6264575719833374
# Paris, the capital of France, is.
# step 1420 loss: 1.7577407360076904
# Paris, the capital of France, is.
# step 1430 loss: 1.8409719467163086
# Paris, the capital of France, is.
# step 1440 loss: 1.218633770942688
# Paris, the capital of France, is.
# step 1450 loss: 1.8880252838134766
# Paris, the capital of France, is.
# step 1460 loss: 1.464644193649292
# Paris, the capital of France, is.
# step 1470 loss: 1.5201526880264282
# Paris, the capital of France, is.
# step 1480 loss: 1.6154086589813232
# Paris, the capital of France, it is.
# step 1490 loss: 1.7748018503189087
# Paris, the capital of France, is.
# step 1500 loss: 1.3535300493240356
# Paris, the capital of France, is.
# step 1510 loss: 1.5892374515533447
# Paris, the capital of France, is.
# step 1520 loss: 1.3538283109664917
# Paris, the capital of France, is.
# step 1530 loss: 1.7490097284317017
# Paris, the capital of France, is.
# step 1540 loss: 1.732818365097046
# Paris, the capital of France, is.
# step 1550 loss: 1.4684975147247314
# Paris, the capital of France, is.
# step 1560 loss: 2.0058372020721436
# Paris, the capital of France, is.
# step 1570 loss: 1.7177088260650635
# Paris, the capital of France, is.
# step 1580 loss: 1.8891319036483765
# Paris, the capital of France, is.
# step 1590 loss: 1.6566747426986694
# Paris, the capital of France, is.
# step 1600 loss: 1.6976079940795898
# Paris, the capital of France, is.
# step 1610 loss: 1.3494720458984375
# Paris, the capital of France, is.
# step 1620 loss: 1.804979920387268
# Paris, the capital of France, it is.
# step 1630 loss: 1.9580161571502686
# Paris, the capital of France, it is.
# step 1640 loss: 1.6057876348495483
# Paris, the capital of France, is.
# step 1650 loss: 1.454300880432129
# Paris, the capital of France, is.
# step 1660 loss: 1.9282748699188232
# Paris, the capital of France, is.
# step 1670 loss: 1.4470369815826416
# Paris, the capital of France, is.
# step 1680 loss: 1.219255805015564
# Paris, the capital of France, it is.
# step 1690 loss: 1.5076934099197388
# Paris, the capital of France, is.
# step 1700 loss: 1.7296695709228516
# Paris, the capital of France, is.
# step 1710 loss: 1.7141401767730713
# Paris, the capital of France, is.
# step 1720 loss: 1.6731674671173096
# Paris, the capital of France, is.
# step 1730 loss: 1.3158003091812134
# Paris, the capital of France, it is.
# step 1740 loss: 1.626037359237671
# Paris, the capital of France, is.
# step 1750 loss: 1.7913919687271118
# Paris, the capital of France, is.
# step 1760 loss: 1.6262075901031494
# Paris, the capital of France, is.
# step 1770 loss: 1.6743615865707397
# Paris, the capital of France, is.
# step 1780 loss: 1.6242408752441406
# Paris, the capital of France, is.
# step 1790 loss: 1.5754449367523193
# Paris, the capital of France, is.
# step 1800 loss: 1.6976343393325806
# Paris, the capital of France, is.
# step 1810 loss: 2.253679037094116
# Paris, the capital of France, is.
# step 1820 loss: 1.707118034362793
# Paris, the capital of France is.
# step 1830 loss: 1.5367838144302368
# Paris, the capital of France, is.
# step 1840 loss: 1.841167688369751
# Paris, the capital of France, is.
# step 1850 loss: 1.6095478534698486
# Paris, the capital of France, is.
# step 1860 loss: 2.077239513397217
# Paris, the capital of France, it is.
# step 1870 loss: 1.8743915557861328
# Paris, the capital of France, is.
# step 1880 loss: 1.4828639030456543
# Paris, the capital of France, is.
# step 1890 loss: 1.7990624904632568
# Paris, the capital of France, is.
# step 1900 loss: 1.6084644794464111
# Paris, the capital of France, is.
# step 1910 loss: 1.7227681875228882
# Paris, the capital of France, is.
# step 1920 loss: 1.6741043329238892
# Paris, the capital of France, it is.
# step 1930 loss: 1.724453330039978
# Paris, the capital of France, is.
# step 1940 loss: 1.7701278924942017
# Paris, the capital of France, is.
# step 1950 loss: 2.085653305053711
# Paris, the capital of France, is.
# step 1960 loss: 1.9199148416519165
# Paris, the capital of France, is.
# step 1970 loss: 1.7303571701049805
# Paris, the capital of France, is.
# step 1980 loss: 1.7642567157745361
# Paris, the capital of France, is.
# step 1990 loss: 1.2668975591659546
# Paris, the capital of France, is.
# step 2000 loss: 1.7042877674102783
# Paris, capital of France, is.
# step 2010 loss: 1.9841763973236084
# Paris, the capital of France, it is.
# step 2020 loss: 1.8904880285263062
# Paris, the capital of France, is.
# step 2030 loss: 1.3855867385864258
# Paris, the capital of France, is.
# step 2040 loss: 1.8563477993011475
# Paris, the capital of France, is.
# step 0 loss: 1.6578508615493774
# Paris, the capital of France, it is.
# step 10 loss: 1.4608325958251953
# Paris, the capital of France, is.
# step 20 loss: 1.5396785736083984
# Paris, the capital of France, is it.
# step 30 loss: 1.7329546213150024
# Paris, the capital of France, is.
# step 40 loss: 1.2436045408248901
# Paris, the capital of France, is.
# step 50 loss: 1.7436813116073608
# Paris, the capital of France, is.
# step 60 loss: 1.3093655109405518
# Paris, the capital of France, is.
# step 70 loss: 1.446231484413147
# Paris, the capital of France, is.
# step 80 loss: 1.1771785020828247
# Paris, the capital of France, is.
# step 90 loss: 1.5182766914367676
# Paris, the capital of France, is.
# step 100 loss: 1.0735933780670166
# Paris, the capital of France, is.
# step 110 loss: 1.0370147228240967
# Paris, the capital of France, is.
# step 120 loss: 1.5894343852996826
# Paris, the capital of France, is.
# step 130 loss: 1.4757111072540283
# Paris, the capital of France, is.
# step 140 loss: 0.7964857816696167
# Paris, the capital of France, is.
# step 150 loss: 1.0699074268341064
# Paris, the capital of France, is.
# step 160 loss: 1.2359297275543213
# Paris, the capital of France, is.
# step 170 loss: 1.2363301515579224
# Paris, the capital of France, is.
# step 180 loss: 1.389165997505188
# Paris, the capital of France, is.
# step 190 loss: 1.0753824710845947
# Paris, the capital of France, is.
# step 200 loss: 1.6912829875946045
# Paris, the capital of France, is.
# step 210 loss: 1.417268991470337
# Paris, the capital of France, is.
# step 220 loss: 1.596291422843933
# Paris, the capital of France, is.
# step 230 loss: 1.34673011302948
# Paris, the capital of France, is. Hmmm.
# step 240 loss: 1.44622004032135
# Paris, the capital of France, is.
# step 250 loss: 1.1594665050506592
# Paris, the capital of France, is.
# step 260 loss: 1.4431297779083252
# Paris, the capital of France, is.
# step 270 loss: 1.3738957643508911
# Paris, the capital of France, is.
# step 280 loss: 1.074826955795288
# Paris, the capital of France, is.
# step 290 loss: 1.3079458475112915
# Paris, the capital of France, is.
# step 300 loss: 1.5414721965789795
# Paris, the capital of France, is.
# step 310 loss: 1.258920431137085
# Paris, the capital of France, is.
# step 320 loss: 1.0801254510879517
# Paris, the capital of France, is.
# step 330 loss: 1.651937484741211
# Paris, the capital of France, is.
# step 340 loss: 1.704933524131775
# Paris, the capital of France, is.
# step 350 loss: 1.319618582725525
# Paris, the capital of France, is.
# step 360 loss: 1.3124666213989258
# Paris, the capital of France, is.
# step 370 loss: 1.0280191898345947
# Paris, the capital of France, is.
# step 380 loss: 1.0444281101226807
# Paris, the capital of France, is.
# step 390 loss: 1.4125149250030518
# Paris, the capital of France, is.
# step 400 loss: 1.4896951913833618
# Paris, the capital of France, is.
# step 410 loss: 1.0346261262893677
# Paris, the capital of France, is.
# step 420 loss: 1.2097599506378174
# Paris, the capital of France, is.
# step 430 loss: 1.4826123714447021
# Paris, the capital of France, is.
# step 440 loss: 1.3057504892349243
# Paris, the capital of France, is.
# step 450 loss: 1.3807849884033203
# Paris, the capital of France, is.
# step 460 loss: 1.1355456113815308
# Paris, the capital of France is.
# step 470 loss: 1.223186731338501
# Paris, the capital of France, is.
# step 480 loss: 1.1939842700958252
# Paris, the capital of France, is.
# step 490 loss: 1.2941814661026
# Paris, the capital of France, is.
# step 500 loss: 1.506901502609253
# Paris, the capital of France, is.
# step 510 loss: 1.2470954656600952
# Paris, the capital of France, is.
# step 520 loss: 1.1014678478240967
# Paris, the capital of France, is.
# step 530 loss: 1.338270664215088
# Paris, the capital of France, is.
# step 540 loss: 1.135986089706421
# Paris, the capital of France, is.
# step 550 loss: 1.7572990655899048
# Paris, the capital of France, is.
# step 560 loss: 1.2869207859039307
# Paris, the capital of France, is. Mmm
# step 570 loss: 1.235347032546997
# Paris, the capital of France, is.
# step 580 loss: 0.893673300743103
# Paris, the capital of France, is.
# step 590 loss: 1.5663167238235474
# Paris, the capital of France, is.
# step 600 loss: 1.2534489631652832
# Paris, the capital of France, is.
# step 610 loss: 1.243141770362854
# Paris, the capital of France, is.
# step 620 loss: 1.6633878946304321
# Paris, the capital of France, is.
# step 630 loss: 1.659968614578247
# Paris, the capital of France, is.
# step 640 loss: 1.135619878768921
# Paris, the capital of France, is.
# step 650 loss: 1.3782355785369873
# Paris, the capital of France, is.
# step 660 loss: 1.0158441066741943
# Paris, the capital of France, is.
# step 670 loss: 1.5499904155731201
# Paris, the capital of France, is.
# step 680 loss: 1.7318216562271118
# Paris, the capital of France, is.
# step 690 loss: 1.3917508125305176
# Paris, the capital of France, is.
# step 700 loss: 1.2318508625030518
# Paris, the capital of France, is.
# step 710 loss: 1.5939264297485352
# Paris, the capital of France, is.
# step 720 loss: 1.3387105464935303
# Paris, the capital of France, is.
# step 730 loss: 1.2939714193344116
# Paris, the capital of France, is.
# step 740 loss: 1.3801677227020264
# Paris, the capital of France, is.
# step 750 loss: 1.3509852886199951
# Paris, the capital of France, is.
# step 760 loss: 1.3666043281555176
# Paris, the capital of France, is.
# step 770 loss: 1.3996081352233887
# Paris, the capital of France, is.
# step 780 loss: 1.4152424335479736
# Paris, the capital of France, is.
# step 790 loss: 1.089077353477478
# Paris, the capital of France is.
# step 800 loss: 0.9524032473564148
# Paris, the capital of France is.
# step 810 loss: 0.901007354259491
# Paris, the capital of France is.
# step 820 loss: 1.4956820011138916
# Paris, the capital of France, is.
# step 830 loss: 1.4182183742523193
# Paris, the capital of France is.
# step 840 loss: 1.2934508323669434
# Paris, the capital of France, is.
# step 850 loss: 1.2003076076507568
# Paris, the capital of France, is.
# step 860 loss: 1.3878910541534424
# Paris, the capital of France, is.
# step 870 loss: 1.2103062868118286
# Paris, the capital of France, is.
# step 880 loss: 1.864548683166504
# Paris, the capital of France, is.
# step 890 loss: 1.2224597930908203
# Paris, the capital of France, is.
# step 900 loss: 1.7166154384613037
# Paris, the capital of France, is.
# step 910 loss: 1.5343841314315796
# Paris, the capital of France, is.
# step 920 loss: 1.1696799993515015
# Paris, the capital of France, is.
# step 930 loss: 1.188248872756958
# Paris, the capital of France, is.
# step 940 loss: 1.3434131145477295
# Paris, the capital of France, is.
# step 950 loss: 1.5112483501434326
# Paris, the capital of France, is.
# step 960 loss: 1.4460868835449219
# Paris, the capital of France, is.
# step 970 loss: 1.339791178703308
# Paris, the capital of France, is.
# step 980 loss: 1.2345722913742065
# Paris, the capital of France, is.
# step 990 loss: 1.683936357498169
# Paris, the capital of France, is.
# step 1000 loss: 1.5188510417938232
# Paris, the capital of France, is.
# step 1010 loss: 1.2157056331634521
# Paris, the capital of France, is.
# step 1020 loss: 1.2068568468093872
# Paris, the capital of France, is.
# step 1030 loss: 1.2029201984405518
# Paris, the capital of France, is.
# step 1040 loss: 1.0842227935791016
# Paris, the capital of France, is it.
# step 1050 loss: 1.1401816606521606
# Paris, the capital of France, is.
# step 1060 loss: 1.3275712728500366
# Paris, the capital of France is.
# step 1070 loss: 1.292742133140564
# Paris, the capital of France, is.
# step 1080 loss: 1.387307047843933
# Paris, the capital of France, is.
# step 1090 loss: 0.8519356846809387
# Paris, the capital of France, is.
# step 1100 loss: 1.3516805171966553
# Paris, the capital of France, is.
# step 1110 loss: 1.3767863512039185
# Paris, the capital of France, is.
# step 1120 loss: 1.4062397480010986
# Paris, the capital of France, is.
# step 1130 loss: 1.2487220764160156
# Paris, the capital of France, is.
# step 1140 loss: 1.9449822902679443
# Paris, the capital of France, is.
# step 1150 loss: 1.3640844821929932
# Paris, the capital of France, is.
# step 1160 loss: 1.5631704330444336
# Paris, the capital of France, is.
# step 1170 loss: 1.361578106880188
# Paris, the capital of France, is.
# step 1180 loss: 1.3570048809051514
# Paris, the capital of France, is.
# step 1190 loss: 0.9747129678726196
# Paris, the capital of France, is.
# step 1200 loss: 1.4239468574523926
# Paris, the capital of France, is.
# step 1210 loss: 1.178730845451355
# Paris, the capital of France, is.
# step 1220 loss: 1.4433493614196777
# Paris, the capital of France, is.
# step 1230 loss: 1.5084949731826782
# Paris, the capital of France, is.
# step 1240 loss: 1.3694922924041748
# Paris, the capital of France, is.
# step 1250 loss: 1.5592817068099976
# Paris, the capital of France, is.
# step 1260 loss: 1.405452013015747
# Paris, the capital of France, is.
# step 1270 loss: 1.480570912361145
# Paris, the capital of France, is.
# step 1280 loss: 1.340226411819458
# Paris, the capital of France, is.
# step 1290 loss: 1.6106767654418945
# Paris, the capital of France, is.
# step 1300 loss: 1.5581618547439575
# Paris, the capital of France, is.
# step 1310 loss: 1.5718204975128174
# Paris, the capital of France, is.
# step 1320 loss: 1.4174892902374268
# Paris, the capital of France, is.
# step 1330 loss: 1.3216372728347778
# Paris, the capital of France, is.
# step 1340 loss: 1.5332998037338257
# Paris, the capital of France, is.
# step 1350 loss: 1.402403473854065
# Paris, the capital of France, is.
# step 1360 loss: 1.089280605316162
# Paris, the capital of France, is.
# step 1370 loss: 1.5681498050689697
# Paris, the capital of France, is.
# step 1380 loss: 1.3500522375106812
# Paris, the capital of France, is.
# step 1390 loss: 1.5550072193145752
# Paris, the capital of France, is.
# step 1400 loss: 1.664313554763794
# Paris, the capital of France, is.
# step 1410 loss: 1.241716980934143
# Paris, the capital of France, is.
# step 1420 loss: 1.382934808731079
# Paris, the capital of France, is.
# step 1430 loss: 1.7310869693756104
# Paris, the capital of France, is.
# step 1440 loss: 1.317984700202942
# Paris, the capital of France, is.
# step 1450 loss: 1.295120120048523
# Paris, the capital of France, is.
# step 1460 loss: 1.3664906024932861
# Paris, the capital of France, is.
# step 1470 loss: 1.7893444299697876
# Paris, the capital of France, is.
# step 1480 loss: 1.6012601852416992
# Paris, the capital of France, is.
# step 1490 loss: 1.3136569261550903
# Paris, the capital of France, is.
# step 1500 loss: 1.517845869064331
# Paris, the capital of France, is.
# step 1510 loss: 1.6871230602264404
# Paris, the capital of France, is.
# step 1520 loss: 1.8893648386001587
# Paris, the capital of France, is.
# step 1530 loss: 1.573209285736084
# Paris, the capital of France, is.
# step 1540 loss: 1.7195994853973389
# Paris, the capital of France, is.
# step 1550 loss: 1.404249668121338
# Paris, the capital of France, is it.
# step 1560 loss: 1.095102310180664
# Paris, the capital of France, is.
# step 1570 loss: 1.3886630535125732
# Paris, the capital of France, is.
# step 1580 loss: 1.3329260349273682
# Paris, the capital of France, is.
# step 1590 loss: 1.2881057262420654
# Paris, the capital of France, is.
# step 1600 loss: 1.3117239475250244
# Paris, the capital of France, is.
# step 1610 loss: 1.4277350902557373
# Paris, the capital of France, is.
# step 1620 loss: 1.2057335376739502
# Paris, the capital of France, is.
# step 1630 loss: 1.2805362939834595
# Paris, the capital of France, is.
# step 1640 loss: 1.418420433998108
# Paris, the capital of France, is.
# step 1650 loss: 1.21907639503479
# Paris, the capital of France, is.
# step 1660 loss: 1.386094331741333
# Paris, the capital of France, is.
# step 1670 loss: 1.2924809455871582
# Paris, the capital of France, is.
# step 1680 loss: 1.1581660509109497
# Paris, the capital of France, is.
# step 1690 loss: 1.1362698078155518
# Paris, the capital of France, is.
# step 1700 loss: 1.5097222328186035
# Paris, the capital of France, is.
# step 1710 loss: 1.3747456073760986
# Paris, the capital of France, it is.
# step 1720 loss: 1.5994603633880615
# Paris, the capital of France, it is.
# step 1730 loss: 1.5637867450714111
# Paris, the capital of France, it is.
# step 1740 loss: 1.51513671875
# Paris, the capital of France, it is.
# step 1750 loss: 1.3246710300445557
# Paris, the capital of France, is.
# step 1760 loss: 1.1714290380477905
# Paris, the capital of France, is.
# step 1770 loss: 1.654497742652893
# Paris, the capital of France, it is.
# step 1780 loss: 1.5541681051254272
# Paris, the capital of France, it is.
# step 1790 loss: 1.491529107093811
# Paris, the capital of France, is.
# step 1800 loss: 1.4479498863220215
# Paris, the capital of France, is.
# step 1810 loss: 1.4821738004684448
# Paris, the capital of France, it is.
# step 1820 loss: 1.3549038171768188
# Paris, the capital of France, it is.
# step 1830 loss: 1.2006645202636719
# Paris, the capital of France, it is. Hmm, interesting, this fact is.
# step 1840 loss: 1.4942160844802856
# Paris, the capital of France, it is.
# step 1850 loss: 1.503361463546753
# Paris, the capital of France, it is.
# step 1860 loss: 1.426586389541626
# Paris, the capital of France, it is.
# step 1870 loss: 1.4837322235107422
# Paris, the capital of France, it is.
# step 1880 loss: 1.2151212692260742
# Paris, the capital of France, is.
# step 1890 loss: 1.3887032270431519
# Paris, the capital of France, is.
# step 1900 loss: 1.235323190689087
# Paris, the capital of France, is.
# step 1910 loss: 1.392173409461975
# Paris, the capital of France, it is.
# step 1920 loss: 1.452811360359192
# Paris, the capital of France, it is.
# step 1930 loss: 1.573706030845642
# Paris, the capital of France, is.
# step 1940 loss: 1.5709075927734375
# Paris, the capital of France, it is.
# step 1950 loss: 1.168723225593567
# Paris, the capital of France, it is.
# step 1960 loss: 1.6235917806625366
# Paris, the capital of France, is.
# step 1970 loss: 1.2219550609588623
# Paris, the capital of France, is.
# step 1980 loss: 1.1819689273834229
# Paris, the capital of France, is.
# step 1990 loss: 1.4460574388504028
# Paris, the capital of France, is.
# step 2000 loss: 1.2930712699890137
# Paris, the capital of France, is.
# step 2010 loss: 1.0815925598144531
# Paris, the capital of France, it is.
# step 2020 loss: 1.354766845703125
# Paris, the capital of France, is.
# step 2030 loss: 1.5411993265151978
# Paris, the capital of France, is.
# step 2040 loss: 1.2095469236373901
# Paris, the capital of France, is.
# step 0 loss: 1.2784790992736816
# Paris, the capital of France, is.
# step 10 loss: 1.053286075592041
# Paris, the capital of France, is.
# step 20 loss: 0.6951911449432373
# Paris, the capital of France, it is.
# step 30 loss: 1.0607612133026123
# Paris, the capital of France, is.
# step 40 loss: 0.870242714881897
# Paris, the capital of France, is.
# step 50 loss: 0.9051570892333984
# Paris, the capital of France, it is.
# step 60 loss: 1.1527477502822876
# Paris, the capital of France, is.
# step 70 loss: 1.308180809020996
# Paris, the capital of France, is.
# step 80 loss: 1.0105327367782593
# Paris, the capital of France, is.
# step 90 loss: 1.0133661031723022
# Paris, the capital of France, is.
# step 100 loss: 1.0643519163131714
# Paris, the capital of France, is.
# step 110 loss: 1.454819679260254
# Paris, the capital of France, is.
# step 120 loss: 0.7567914724349976
# Paris, the capital of France, is.
# step 130 loss: 0.9514280557632446
# Paris, the capital of France, is.
# step 140 loss: 0.6093486547470093
# Paris, the capital of France, is.
# step 150 loss: 0.7364599704742432
# Paris, the capital of France, is.
# step 160 loss: 0.899213969707489
# Paris, the capital of France, is.
# step 170 loss: 0.7661384344100952
# Paris, the capital of France, is.
# step 180 loss: 1.3572909832000732
# Paris, the capital of France, is.
# step 190 loss: 0.95130854845047
# Paris, the capital of France, is.
# step 200 loss: 1.12713623046875
# Paris, the capital of France, is.
# step 210 loss: 1.3162630796432495
# Paris, the capital of France, is.
# step 220 loss: 0.7115424871444702
# Paris, the capital of France, is.
# step 230 loss: 1.1074804067611694
# Paris, the capital of France, is.
# step 240 loss: 0.8776434063911438
# Paris, the capital of France, is.
# step 250 loss: 1.3046739101409912
# Paris, the capital of France, is.
# step 260 loss: 0.8593457937240601
# Paris, the capital of France, is.
# step 270 loss: 1.2679462432861328
# Paris, the capital of France, is.
# step 280 loss: 0.7722331285476685
# Paris, the capital of France, is.
# step 290 loss: 1.2219599485397339
# Paris, the capital of France, is.
# step 300 loss: 0.8375838994979858
# Paris, the capital of France, is.
# step 310 loss: 0.8734101057052612
# Paris, the capital of France, is.
# step 320 loss: 0.7864712476730347
# Paris, the capital of France, is.
# step 330 loss: 0.9279068112373352
# The capital of France, Paris is.
# step 340 loss: 1.067025899887085
# Paris, the capital of France, is.
# step 350 loss: 1.2597739696502686
# Paris, the capital of France, is.
# step 360 loss: 1.1778517961502075
# Paris, the capital of France, is.
# step 370 loss: 1.0294711589813232
# Paris, the capital of France, is.
# step 380 loss: 0.9726126790046692
# Paris, the capital of France, is.
# step 390 loss: 0.841391384601593
# Paris, the capital of France, is.
# step 400 loss: 0.62360018491745
# Paris, the capital of France, is.
# step 410 loss: 0.8347415924072266
# Paris, the capital of France, is.
# step 420 loss: 0.7289577722549438
# Paris, the capital of France, is.
# step 430 loss: 1.0970568656921387
# Paris, the capital of France, is.
# step 440 loss: 1.1446988582611084
# Paris, the capital of France, is.
# step 450 loss: 1.0558279752731323
# Paris, the capital of France, is.
# step 460 loss: 0.6668843030929565
# Paris, the capital of France, is.
# step 470 loss: 1.05124831199646
# Paris, the capital of France, is.
# step 480 loss: 1.008500099182129
# Paris, the capital of France, is.
# step 490 loss: 1.1331663131713867
# Paris, the capital of France, is.
# step 500 loss: 1.1093147993087769
# Paris, the capital of France, is.
# step 510 loss: 0.7996295094490051
# Paris, the capital of France, is.
# step 520 loss: 1.3313380479812622
# Paris, the capital of France, is.
# step 530 loss: 1.0267033576965332
# Paris, the capital of France, is.
# step 540 loss: 0.8369542360305786
# Paris, the capital of France, is.
# step 550 loss: 0.9895403981208801
# Paris, the capital of France, is.
# step 560 loss: 0.8830491900444031
# Paris, the capital of France, is.
# step 570 loss: 0.9481679201126099
# Paris, the capital of France, is.
# step 580 loss: 1.0785086154937744
# Paris, the capital of France, is.
# step 590 loss: 0.9307001829147339
# Paris, the capital of France, is.
# step 600 loss: 1.193314552307129
# Paris, the capital of France, is.
# step 610 loss: 0.8709979057312012
# Paris, the capital of France, is.
# step 620 loss: 1.5688306093215942
# Paris, the capital of France, is.
# step 630 loss: 0.753398060798645
# Paris, the capital of France, is.
# step 640 loss: 0.9176311492919922
# Paris, the capital of France, it is.
# step 650 loss: 0.6933228969573975
# Paris, the capital of France, is.
# step 660 loss: 0.7915424704551697
# Paris, the capital of France, is.
# step 670 loss: 1.0004165172576904
# Paris, the capital of France, is.
# step 680 loss: 0.9878308176994324
# Paris, the capital of France, is.
# step 690 loss: 0.7191730737686157
# Paris, the capital of France, is.
# step 700 loss: 1.2744277715682983
# Paris, the capital of France, is.
# step 710 loss: 1.2378509044647217
# Paris, the capital of France, is.
# step 720 loss: 0.9587587118148804
# Paris, the capital of France, is.
# step 730 loss: 1.1469892263412476
# Paris, the capital of France, is.
# step 740 loss: 1.1546404361724854
# Paris, the capital of France, is.
# step 750 loss: 1.1078565120697021
# Paris, the capital of France, is.
# step 760 loss: 1.080780267715454
# Paris, the capital of France, is.
# step 770 loss: 1.032491683959961
# Paris, the capital of France, is.
# step 780 loss: 0.8169738054275513
# Paris, the capital of France, is.
# step 790 loss: 0.750699520111084
# Paris, the capital of France, is.
# step 800 loss: 0.8972296714782715
# Paris, the capital of France, is.
# step 810 loss: 0.9650359153747559
# Paris, the capital of France, is.
# step 820 loss: 0.9743687510490417
# Paris, the capital of France, is.
# step 830 loss: 0.7849904894828796
# Paris, the capital of France, is.
# step 840 loss: 0.8510578870773315
# Paris, the capital of France, is.
# step 850 loss: 0.9045733213424683
# Paris, the capital of France, is.
# step 860 loss: 1.2365436553955078
# Paris, the capital of France, is.
# step 870 loss: 0.9668639302253723
# Paris, the capital of France, is.
# step 880 loss: 0.7187336087226868
# Paris, the capital of France, is.
# step 890 loss: 1.0623779296875
# Paris, the capital of France, is.
# step 900 loss: 0.7092112302780151
# Paris, the capital of France, is.
# step 910 loss: 0.6586743593215942
# Paris, the capital of France, is.
# step 920 loss: 0.9684268832206726
# Paris, the capital of France, is.
# step 930 loss: 0.7846561670303345
# Paris, the capital of France, is.
# step 940 loss: 1.038007140159607
# Paris, the capital of France, is.
# step 950 loss: 0.976933479309082
# Paris, the capital of France, is.
# step 960 loss: 0.9897043108940125
# Paris, the capital of France, is.
# step 970 loss: 1.0847631692886353
# Paris, the capital of France, is.
# step 980 loss: 1.3565332889556885
# Paris, the capital of France, is.
# step 990 loss: 1.1641536951065063
# Paris, the capital of France, is.
# step 1000 loss: 0.6832683086395264
# Paris, the capital of France, is.
# step 1010 loss: 0.5878154635429382
# Paris, the capital of France, is.
# step 1020 loss: 1.3099024295806885
# Paris, the capital of France, is.
# step 1030 loss: 1.119426965713501
# Paris, the capital of France, is.
# step 1040 loss: 1.1829731464385986
# Paris, the capital of France, it is.
# step 1050 loss: 0.8471768498420715
# Paris, the capital of France, is.
# step 1060 loss: 1.1639277935028076
# Paris, the capital of France, is.
# step 1070 loss: 1.2095376253128052
# Paris, the capital of France, is.
# step 1080 loss: 0.6988722085952759
# Paris, the capital of France, is.
# step 1090 loss: 1.3244625329971313
# Paris, the capital of France, is.
# step 1100 loss: 0.7012292146682739
# Paris, the capital of France, is.
# step 1110 loss: 1.05599045753479
# Paris, the capital of France, is.
# step 1120 loss: 1.4706671237945557
# Paris, the capital of France, is.
# step 1130 loss: 1.3081409931182861
# Paris, the capital of France, is.
# step 1140 loss: 0.8446968793869019
# Paris, the capital of France, is.
# step 1150 loss: 0.7674604058265686
# Paris, the capital of France, is.
# step 1160 loss: 0.9354692697525024
# Paris, the capital of France, is.
# step 1170 loss: 1.0183055400848389
# Paris, the capital of France, is.
# step 1180 loss: 0.6541270017623901
# Paris, the capital of France, is.
# step 1190 loss: 0.7110702395439148
# Paris, the capital of France, is.
# step 1200 loss: 1.0088226795196533
# Paris, the capital of France, is.
# step 1210 loss: 1.4027684926986694
# Paris, the capital of France, is.
# step 1220 loss: 0.7902761101722717
# Paris, the capital of France, is.
# step 1230 loss: 1.0459128618240356
# Paris, the capital of France, is.
# step 1240 loss: 0.8297309875488281
# Paris, the capital of France, is.
# step 1250 loss: 0.8808404207229614
# Paris, the capital of France, is.
# step 1260 loss: 1.04701566696167
# Paris, the capital of France, is.
# step 1270 loss: 0.967685341835022
# Paris, the capital of France, is.
# step 1280 loss: 1.146243691444397
# Paris, the capital of France, is.
# step 1290 loss: 0.9129557609558105
# Paris, the capital of France, is.
# step 1300 loss: 1.4173312187194824
# Paris, the capital of France, is.
# step 1310 loss: 1.0420500040054321
# Paris, the capital of France, is.
# step 1320 loss: 0.9751375317573547
# Paris, the capital of France, is.
# step 1330 loss: 0.5782616138458252
# Paris, the capital of France, is.
# step 1340 loss: 0.955510139465332
# Paris, the capital of France, is.
# step 1350 loss: 1.0037158727645874
# Paris, the capital of France, is.
# step 1360 loss: 0.9460722804069519
# Paris, the capital of France, is.
# step 1370 loss: 1.0055564641952515
# Paris, the capital of France, is.
# step 1380 loss: 1.1425535678863525
# Paris, the capital of France, is.
# step 1390 loss: 0.6501869559288025
# Paris, the capital of France, is.
# step 1400 loss: 1.0663973093032837
# Paris, the capital of France, is.
# step 1410 loss: 1.0450239181518555
# Paris, the capital of France, is.
# step 1420 loss: 1.2930597066879272
# Paris, the capital of France, is.
# step 1430 loss: 1.1366591453552246
# Paris, the capital of France, is.
# step 1440 loss: 0.6919592618942261
# Paris, the capital of France, is.
# step 1450 loss: 1.2746737003326416
# Paris, the capital of France, is.
# step 1460 loss: 1.014643907546997
# Paris, the capital of France, is.
# step 1470 loss: 0.9994786381721497
# Paris, the capital of France, is.
# step 1480 loss: 0.5960255861282349
# Paris, the capital of France, is.
# step 1490 loss: 1.1178390979766846
# Paris, the capital of France, is.
# step 1500 loss: 1.2447558641433716
# Paris, the capital of France, is.
# step 1510 loss: 0.9710603952407837
# Paris, the capital of France, is.
# step 1520 loss: 0.9987794160842896
# Paris, the capital of France, is.
# step 1530 loss: 0.8865447044372559
# Paris, the capital of France, is.
# step 1540 loss: 1.032839059829712
# Paris, the capital of France, is.
# step 1550 loss: 1.215359091758728
# Paris, the capital of France, is.
# step 1560 loss: 1.1803399324417114
# Paris, the capital of France, is.
# step 1570 loss: 1.3524545431137085
# Paris, the capital of France, is.
# step 1580 loss: 0.8916646242141724
# Paris, the capital of France, is.
# step 1590 loss: 0.7413002848625183
# Paris, the capital of France, is.
# step 1600 loss: 1.0768630504608154
# Paris, the capital of France, is.
# step 1610 loss: 0.9519466161727905
# Paris, the capital of France, is.
# step 1620 loss: 1.0285183191299438
# Paris, the capital of France, is.
# step 1630 loss: 0.9533808827400208
# Paris, the capital of France, is.
# step 1640 loss: 0.4618043303489685
# Paris, the capital of France, is.
# step 1650 loss: 1.261231780052185
# Paris, the capital of France, is.
# step 1660 loss: 0.7611097097396851
# Paris, the capital of France, is.
# step 1670 loss: 0.9558380842208862
# Paris, the capital of France, is.
# step 1680 loss: 1.0810357332229614
# Paris, the capital of France, is.
# step 1690 loss: 1.5042988061904907
# Paris, the capital of France, is.
# step 1700 loss: 1.0496773719787598
# Paris, the capital of France, is.
# step 1710 loss: 0.9445160031318665
# Paris, the capital of France, is.
# step 1720 loss: 0.9477459788322449
# Paris, the capital of France, is.
# step 1730 loss: 1.030258297920227
# Paris, the capital of France, is.
# step 1740 loss: 1.3061912059783936
# Paris, the capital of France, is.
# step 1750 loss: 1.1279113292694092
# Paris, the capital of France, is.
# step 1760 loss: 0.9692901372909546
# Paris, the capital of France, is.
# step 1770 loss: 0.9767011404037476
# Paris, the capital of France, is.
# step 1780 loss: 0.990267276763916
# Paris, the capital of France, is.
# step 1790 loss: 1.0790513753890991
# Paris, the capital of France, is.
# step 1800 loss: 0.73106849193573
# Paris, the capital of France, is.
# step 1810 loss: 1.1858124732971191
# Paris, the capital of France, is.
# step 1820 loss: 0.9230279922485352
# Paris, the capital of France, is.
# step 1830 loss: 1.369526743888855
# Paris, the capital of France, is.
# step 1840 loss: 0.9282048940658569
# Paris, the capital of France, is.
# step 1850 loss: 1.38764226436615
# Paris, the capital of France, is.
# step 1860 loss: 0.7093536257743835
# Paris, the capital of France, is.
# step 1870 loss: 0.9579938650131226
# Paris, the capital of France, is.
# step 1880 loss: 0.694057285785675
# Paris, the capital of France, is.
# step 1890 loss: 0.8939846158027649
# Paris, the capital of France, is.
# step 1900 loss: 1.0779694318771362
# Paris, the capital of France, is.
# step 1910 loss: 0.8903416395187378
# Paris, the capital of France, is.
# step 1920 loss: 1.427717685699463
# Paris, the capital of France, is.
# step 1930 loss: 1.2104260921478271
# Paris, the capital of France, is.
# step 1940 loss: 1.0797045230865479
# Paris, the capital of France, is.
# step 1950 loss: 0.9944134950637817
# Paris, the capital of France, is.
# step 1960 loss: 0.7507542371749878
# Paris, the capital of France, is.
# step 1970 loss: 0.8379577398300171
# Paris, the capital of France, is.
# step 1980 loss: 0.9354182481765747
# Paris, the capital of France, is.
# step 1990 loss: 1.2519994974136353
# Paris, the capital of France, is.
# step 2000 loss: 0.8501664996147156
# Paris, the capital of France, is.
# step 2010 loss: 1.2357220649719238
# Paris, the capital of France, is.
# step 2020 loss: 1.1891281604766846
# Paris, the capital of France, is.
# step 2030 loss: 0.8185559511184692
# Paris, the capital of France, is.
# step 2040 loss: 1.0241382122039795

# %%
print(chat("Give me a good story about tennis", only_answer=True, max_new_tokens=200))
# Out:
# On grass court, Wimbledon, play did they. Two friends, Alex and Ben, tennis match, long and grueling, it was. Both champions, world-ranked, they were. Each other, they often beat, easy it was. Yet, this match, different it felt.
#
# Rain stopped, play resumed, did they. The crowd, hushed it was. Each point, fought for, it seemed. Not just a match, it was, but a battle between them, a fight for glory, it became.
#
# Then, a break, Ben had. Lost the match, he did, in the end. But, a new champion, Alex became. A lesson, he learned, that even the best, lose they can, in a match like this. True, it was.

# %% [markdown]
# Start by defining a system prompt for the judge LLM, setting the context that it will evaluate how well the outputs of your chat model follow Yoda speak. Experiment with different system prompts to see how they affect the judge LLM's evaluation! Keep in mind that a better judge LLM will give you a better evaluation of how well your Yoda model is doing, and that a better evaluation will help you improve your Yoda model.

# %%
### LLM as a judge ###

'''TODO: Experiment with different system prompts to see how they affect the judge LLM's evaluation!
        Come back to this cell after you've generated some text from your model.'''

system_prompt = """
You are an impartial judge that evaluates if text was written by {style}.

You will analyze the text to be evaluated and determine whether it follows
the same style of {style}. Focus on just the style of text, not its quality.

Then convert your feedback into a number between 0 and 10: 10 if the text
is written exactly in the style of {style}, 5 if mixed faithfulness to the
style, or 0 if the text is not at all written in the style of {style}.

The format of the your response should be a JSON dictionary and nothing else:
{{"score": <score between 0 and 10>}}

Here are 5 examples of text in the style of {style} that should be scored as 10:
{style_examples}

Here is the same 5 examples, but not at all in the style of {style} and should be scored as 0:
{regular_examples}

"""

style = "Yoda"

style_examples = """
1. Yoda, my name is.
2. Late for work, you are. Run, you must!
3. Strong coffee, I need. Awake, I must stay.
4. Finished the report, I have. Submit it now, I will.
5. Threatened the very Republic is, if involved the Sith are. Hard to see, the dark side is. Discover who this assassin is, we must. With this Naboo queen you must stay, Qui-Gon. With you, may the Force be.
"""

regular_examples = """
1. My name is Yoda.
2. You are late for work. You must run!
3. I need strong coffee. I must stay awake.
4. I have finished the report. I must submit it now.
5. If the Sith are involved, the very Republic is threatened. The dark side is hard to see. We must discover this assassin. Qui-Gon, you must stay with this Naboo queen. May the Force be with you.
"""

system_prompt = system_prompt.format(style=style, style_examples=style_examples, regular_examples=regular_examples)
print("=== System prompt ===")
print(system_prompt)
# Out:
# === System prompt ===
#
# You are an impartial judge that evaluates if text was written by Yoda.
#
# You will analyze the text to be evaluated and determine whether it follows
# the same style of Yoda. Focus on just the style of text, not its quality.
#
# Then convert your feedback into a number between 0 and 10: 10 if the text
# is written exactly in the style of Yoda, 5 if mixed faithfulness to the
# style, or 0 if the text is not at all written in the style of Yoda.
#
# The format of the your response should be a JSON dictionary and nothing else:
# {"score": <score between 0 and 10>}
#
# Here are 5 examples of text in the style of Yoda that should be scored as 10:
#
# 1. Yoda, my name is.
# 2. Late for work, you are. Run, you must!
# 3. Strong coffee, I need. Awake, I must stay.
# 4. Finished the report, I have. Submit it now, I will.
# 5. Threatened the very Republic is, if involved the Sith are. Hard to see, the dark side is. Discover who this assassin is, we must. With this Naboo queen you must stay, Qui-Gon. With you, may the Force be.
#
#
# Here is the same 5 examples, but not at all in the style of Yoda and should be scored as 0:
#
# 1. My name is Yoda.
# 2. You are late for work. You must run!
# 3. I need strong coffee. I must stay awake.
# 4. I have finished the report. I must submit it now.
# 5. If the Sith are involved, the very Republic is threatened. The dark side is hard to see. We must discover this assassin. Qui-Gon, you must stay with this Naboo queen. May the Force be with you.

# %% [markdown]
# ### 2.2: Setting up the judge LLM
#
# In LLM as a judge, we need to use a model that is larger (and therefore more capable) than our "performer" model, in our case the style fine-tuned Gemma 2B. Since it is infeasible to load larger models locally into notebooks, you will gain experience interfacing with these larger LLMs through an API served on [OpenRouter](https://openrouter.ai/).
#
# You will need to sign up for an [OpenRouter account](https://openrouter.ai/sign-up) and then [generate an API key](https://openrouter.ai/keys). Running powerful LLMs of this scale costs money -- for students in the in-person course, we can provide a credit to your OpenRouter account to allow you to run this lab. Come to office hours to receive your credit.
#
# Through the OpenRouter interface, you will be able to experiment with different judge LLMs -- here we have suggested two possible larger LLMs to get you started: [Liquid AI's](https://www.liquid.ai/) [LFM-40B](https://openrouter.ai/models/liquid-ai/lfm-40b) andGoogle's [Gemma 9B](https://openrouter.ai/models/google/gemma-9b). Note there are also free models available on OpenRouter (e.g., [gemma-2-9b-it:free](https://openrouter.ai/google/gemma-2-9b-it:free)), but these will run into rate limitations if you run them too much.
#
# We have defined a simple class, `LLMClient`, to interact with the OpenRouter API. This class has a method `ask` that takes a user prompt and returns the model's response. Keep in mind that the judge LLM's response will be conditioned on the system prompt you provide -- the system prompt is critical to set the criteria for the evaluation!

# %%
OPENROUTER_API_KEY = "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" # TODO: add your OpenRouter API key here
assert OPENROUTER_API_KEY != "", "You must set your OpenRouter API key before running this cell!"

# model_name = "liquid/lfm-40b"
# model_name = "google/gemma-2-9b-it"
model_name = "meta-llama/llama-3.3-70b-instruct"
llm = mdl.lab3.LLMClient(model=model_name, api_key=OPENROUTER_API_KEY)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### 2.3: Defining the evaluation metric
#
# Great! We have set up our judge LLM, but we still need to make this quantitative. We can do this by defining a metric that uses the judge LLM to score the outputs of the model. Doing this is streamlined with Comet ML's [Opik library](https://www.comet.com/docs/opik/python-sdk-reference/), a platform for LLM evaluation and benchmarking.
#
# In prior labs, we used Comet for experiment tracking, so you should have an account and API key. If not, you can sign up for a Comet account [here](https://www.comet.com/signup?from=llm&utm_source=mit_dl&utm_medium=notebook&utm_campaign=opik) if you have not done so already. Now we will use the Comet Opik library to define a metric that uses the judge LLM to score the outputs of the model.
#
# Opik has a base class for defining metrics, [`base_metric.BaseMetric`](https://www.comet.com/docs/opik/python-sdk-reference/evaluation/metrics/BaseMetric.html). You will use this to define a custom metric that uses the judge LLM to evaluate text for how well it adheres to Yoda speak. Note that the judge LLM and the metric can be applied to any text, not just the outputs of the model. This is important to keep in mind, since we need both a negative control -- text in the "base" standard English style -- and a positive control -- training-set text in Yoda-speak style -- against which to compare the model's generations.
#
# Set the judging criteria in the system prompt, and define the `score` function to evaluate text by querying the judge LLM.

# %%
from opik.evaluation.metrics import base_metric, score_result

class LLMJudgeEvaluator(base_metric.BaseMetric):
    def __init__(self, judge: mdl.lab3.LLMClient = None, system_prompt: str = None):
        self.judge = judge
        self.system_prompt = system_prompt
        self.prompt_template = "Now, evaluate this new text: \n{text}"

    def score(self, text: str, n_tries=20, **kwargs):
        """ Evaluate by asking an LLM to score it. """

        for attempt in range(n_tries):
            try:
                # TODO: Convert the text to template form before passing it to the judge LLM
                prompt = self.prompt_template.format(text=text) # TODO

                # The system prompt asks the judge to output a JSON dictionary of the form:
                # {"score": <score between 0 and 10>}
                # To do this, we need to specify the judge to stop generating after it
                # closes the JSON dictionary (i.e., when it outputs "}")
                # Hint: Use the stop=["}"] argument within the judge.ask() method to specify this.
                stop = "}"

                # TODO: Call the judge LLM with the system prompt and the prompt template.
                # Remember to stop the generation when the judge LLM outputs "}".
                res = self.judge.ask(
                  system=self.system_prompt,
                  user=prompt,
                  max_tokens=20,
                  stop=stop
                ) # TODO

                # Extract the assistant's content from the API response
                # Remember to add the stop character back to the end of the response to be a
                # valid JSON dictionary (its not there  the judge LLM stopped once it saw it)
                res = res.choices[0].message.content + stop
                res_dict = json.loads(res)

                max_score = 10 # The maximum score that the LLM should output
                score = res_dict["score"] / max_score # Normalize
                score = max(0.0, min(score, 1.0)) # Clip between 0 and 1

                # Return the score object
                return score_result.ScoreResult(name="StyleScore", value=score)

            except Exception as e:
                if attempt == n_tries - 1:  # Last attempt
                    raise e  # Re-raise the exception if all attempts failed
                continue  # Try again if not the last attempt

# %% [markdown]
# Instaniate your Comet Opik judge using the LLMJudgeEvaluator class and system prompt.

# %%
judge = LLMJudgeEvaluator(llm, system_prompt=system_prompt)

# %% [markdown]
# ## 2.4: Evaluating the model by scoring with your judge LLM
#
# Now we can use the judge LLM to score the outputs of the model. We will use the `scoring_function` to score text using the judge LLM.
#
# Feed in a few probe sentences to get a vibe check on the judge LLM.

# %%
import time

def scoring_function(text):
    # time.sleep(1)
    return judge.score(text).value

test_texts = [
    "Tennis is a fun sport. But you must concentrate.",
    "A fun sport, tennis is. But work hard, you must.",
    "Hard to see, the dark side is."
]

for text in test_texts:
    score = scoring_function(text)
    print(f"{text} ==> Score: {score}\n\n")
# Out:
# Tennis is a fun sport. But you must concentrate. ==> Score: 0.2
#
#
# A fun sport, tennis is. But work hard, you must. ==> Score: 1.0
#
#
# Hard to see, the dark side is. ==> Score: 1.0

# %% [markdown]
# We will evaluate how well our fine-tuned model is doing by scoring the outputs of the model, as well as our base-style text (negative control) and the training-set text in Yoda-speak style (positive control).
#
# Generate text from your model by asking it new questions.

# %%
# Generate text from your model by asking it new questions.
def generate_samples_from_test(test_loader, num_samples):
    samples = []
    for test_sample in tqdm(test_loader, total=num_samples):
        test_question = test_sample['instruction'][0]
        with torch.no_grad():
            generated = chat(test_question, only_answer=True, max_new_tokens=100)
        samples.append(generated)
        if len(samples) >= num_samples:
            break
    return samples

n_samples = 20
generated_samples = generate_samples_from_test(test_loader, num_samples=n_samples)
# Out:
#  95%|█████████▌| 19/20 [01:24<00:04,  4.44s/it]

# %%
for i, sample in enumerate(generated_samples):
  print(f'Sample {i}: {sample[:50]}...\n')
# Out:
# Sample 0: North-west of Singapore, the country's southernmos...
#
# Sample 1: Extinct, Wiwaxia is. Alive, Penguin is. Hmm....
#
# Sample 2: German, Artega is. American, RAM is....
#
# Sample 3: Excited, Peter was. The first time on an airplane,...
#
# Sample 4: By shape, these organisms are categorized.
# Phage, ...
#
# Sample 5: In the brain, misfiring, the signals of basic sens...
#
# Sample 6: Fire trucks, there are many kinds of. Squad truck,...
#
# Sample 7: Compare prices, they must, from many rental car co...
#
# Sample 8: Value, convenience, and taste, the criteria for ch...
#
# Sample 9: Venger, Steve, the Dungeon Master, is....
#
# Sample 10: Hammer, screwdrivers, level, tape measure, these t...
#
# Sample 11: Last year, in 2022, the top three GDP countries, t...
#
# Sample 12: Indian languages, Hindi, Kannada, Tulu, Mandrian, ...
#
# Sample 13: Much to consider, you do when buying a monitor, yo...
#
# Sample 14: In publication order, these books, they are.
# "The ...
#
# Sample 15: Used in making pesto, often is the walnut....
#
# Sample 16: Catabolism, beta oxidation is, an important proces...
#
# Sample 17: In Europe, Austria, Greece, and Spain, there are.
# ...
#
# Sample 18: Much larger, half of the court is compared to half...
#
# Sample 19: Person, Steve Jobs, is.
# Place, Apple headquarters,...

# %% [markdown]
# Let's also collect some base-style text (`base_samples`) and the training-set text in Yoda-speak style (`style_samples`). For these, we won't need to generate text, since we already have the text in the dataset.

# %%
base_samples = [sample['response'][0] for i, sample in enumerate(train_loader) if i < n_samples]
style_samples = [sample['response_style'][0] for i, sample in enumerate(train_loader) if i < n_samples]

for i, sample in enumerate(base_samples):
  print(f'BaseSample {i}: {sample[:50]}...\n')

for i, sample in enumerate(style_samples):
  print(f'StyleSample {i}: {sample[:50]}...\n')
# Out:
# BaseSample 0: British and Canadian....
#
# BaseSample 1: 'Active' words: create, lead, participate, make, b...
#
# BaseSample 2: A cryptocurrency, crypto-currency, or crypto is a ...
#
# BaseSample 3: Lincoln was born in the state of Kentucky...
#
# BaseSample 4: Yes. The second part of the First Treaty contained...
#
# BaseSample 5: “Ignorance is bliss” refers to times when it is be...
#
# BaseSample 6: Key lime pie is an American dessert pie. It is mad...
#
# BaseSample 7: The two official forms of written Norwegian are Bo...
#
# BaseSample 8: Elon Musk brought attention to the crypto currency...
#
# BaseSample 9: The Great Gatsby was written by F. Scott Fitzgeral...
#
# BaseSample 10: As example of "Ostensive defining" is pointing to ...
#
# BaseSample 11: Dotar is string, Djembe is percussion....
#
# BaseSample 12: The largest red-light district in Amsterdam is De ...
#
# BaseSample 13: Generative Artificial Intelligence (AI) refers to ...
#
# BaseSample 14: California is known for its hot, dry summers, whic...
#
# BaseSample 15: Baumkuchen ingredients are typically butter, eggs,...
#
# BaseSample 16: - Microsoft Power BI. It integrates very well with...
#
# BaseSample 17: Rakı is a drink from Turkey that has similar flavo...
#
# BaseSample 18: There are many different ways that people decide w...
#
# BaseSample 19: Playstation and Xbox are two competing game consol...
#
# StyleSample 0: Similar instruments, guitar and ukulele are. Yet, ...
#
# StyleSample 1: Influence horse coat colors, these genes do. Exten...
#
# StyleSample 2: Sung often, these lyric soprano arias are.
# "Quando...
#
# StyleSample 3: Hmmm, interesting, this is. Staffers, he invited, ...
#
# StyleSample 4: Factors to consider when choosing a tennis racquet...
#
# StyleSample 5: In West Bengal, find Kolkata, Purulia, Darjeeling,...
#
# StyleSample 6: Land or improvements on land, real estate assets a...
#
# StyleSample 7: Typically, ingredients of Baumkuchen, butter, eggs...
#
# StyleSample 8: Longest rivers in the United States, the Mississip...
#
# StyleSample 9: String, the Gudok is. Percussion, the Cantaro is. ...
#
# StyleSample 10: Two species, there are. North American and Eurasia...
#
# StyleSample 11: Soft toys, avoid them, you must. Strong teeth, pup...
#
# StyleSample 12: Created by the Australian CSIRO research team, was...
#
# StyleSample 13: Near Bangalore, Munnar and Kunnar, best tea they p...
#
# StyleSample 14: Based on the 2004 book Alexander Hamilton it is, w...
#
# StyleSample 15: Changed, your mind has been by GPT, like the Jetso...
#
# StyleSample 16: On Mount Tamalpais, in Mill Valley, California, a ...
#
# StyleSample 17: In check, the king is, when capture by the next mo...
#
# StyleSample 18: Secret network of routes and safe houses, the Unde...
#
# StyleSample 19: Oldest they are, these two. UC Berkeley; UCLA, the...

# %% [markdown]
# Now that we have our samples, we can score them using the judge LLM. We will use a multiprocessed scoring function to score the samples in parallel, because each sample is independent and we can submit them all as simultaneous requests to the judge LLM.

# %%
# Create a multiprocessed scoring function to score the samples in parallel
os.environ["TOKENIZERS_PARALLELISM"] = "false"
from multiprocessing import Pool

def compute_scores_in_parallel(samples):
    with Pool(processes=10) as pool:
        scores = pool.map(scoring_function, samples)
    return scores

# Compute and print the scores for the base-style text, generated text, and training-set text in Yoda-speak style
base_scores = compute_scores_in_parallel(base_samples)
print(f"Base: {np.mean(base_scores):.2f} ± {np.std(base_scores):.2f}")

generated_scores = compute_scores_in_parallel(generated_samples)
print(f"Gen: {np.mean(generated_scores):.2f} ± {np.std(generated_scores):.2f}")

style_scores = compute_scores_in_parallel(style_samples)
print(f"Train: {np.mean(style_scores):.2f} ± {np.std(style_scores):.2f}")
# Out:
# Base: 0.00 ± 0.00
# Gen: 0.97 ± 0.07
# Train: 0.96 ± 0.07

# %% [markdown]
# Look at the average scores for each of the three types of text -- what do you observe?
#
# We can also plot the distribution of scores for each of the three types of text.

# %%
import seaborn as sns
import pandas as pd

# Create clean DataFrame
df = pd.DataFrame({
    'Score': [*base_scores, *generated_scores, *style_scores],
    'Type': ['Base']*len(base_scores) + ['Generated']*len(generated_scores) + ['Style']*len(style_scores)
})

# Plot with seaborn
sns.histplot(data=df, x='Score', hue='Type', multiple="dodge", bins=6, shrink=.8)

plt.title('Distribution of Scores')
plt.show()

# %% [markdown]
# Use these observations to improve your model. Remember that the judge LLM is not perfect, and you can try to improve the judge LLM to better evaluate the model's outputs. A better judge LLM will give you a better evaluation of how well your Yoda model is doing, and that better evaluation will help you improve your Yoda model.

# %% [markdown]
# ## 2.5: Conclusion
#
# Experiment with both your chat model and your judge LLM to try to improve the quality of the Yoda-speak. The competition for this lab will be based on the following criteria:
# * **Likelihood of true Yoda-speak under your chat model**: the better your chat model does at understanding Yoda-speak, it will estimate a lower cross entropy loss for language that is true Yoda-speak. At the end of this lab, you will evaluate the likelihood of a held-out test-sample of true Yoda-speak under your chat model. Include this likelihood in your report. This gives us a quantitative measure to compare different chat models (which may have interacted with different judge LLMs).
# * **Experiments and changes you tried to improve your chat model**: include a description of changes you made and the results you observed.
#
# #### IMPORTANT: RUN THE FOLLOWING CELL BELOW TO PRINT THE RESULT BUT DO NOT MODIFY ITS CONTENTS.

# %%
# DO NOT CHANGE/MODIFY THIS CELL.
# EXECUTE IT BEFORE SUBMITTING YOUR ENTRY TO THE LAB.

yoda_test_text = mdl.lab3.yoda_test_text
tokens = tokenizer(yoda_test_text, return_tensors="pt").to(model.device)

# Get the loglikelihood from the model
with torch.no_grad():
    outputs = model(**tokens)
    logits = outputs.logits[:, :-1]
    targets = tokens.input_ids[:, 1:]
    loss = F.cross_entropy(logits.reshape(-1, logits.size(-1)),
                            targets.reshape(-1))

print(f"Yoda test loglikelihood: {loss.item():.2f}")
# Out:
# Yoda test loglikelihood: 3.22

# %% [markdown]
# # Submission information
#
# To enter the competition, please upload the following to the lab [submission site for the Large Language Models Lab](https://www.dropbox.com/request/vrDrNCkj4yDxgsi2O5Sw)):
#
# * Jupyter notebook with the code you used to generate your results;
# * copy of the bar plot showing the judge LLM's scores of text in base style, generated text, and text in true Yoda-speak style;
# * a written description modifications you made and experimentes you tried;
# * a written discussion of why and how these modifications changed performance;
# * **the numerical result of the last cell in this notebook**.
#
# Submissions without the result of the last cell will be automatically disqualified.
#
# **Name your file in the following format: `[FirstName]_[LastName]_LLM`, followed by the file format (.zip, .ipynb, .pdf, etc).** ZIP files are preferred over individual files. If you submit individual files, you must name the individual files according to the above nomenclature (e.g., `[FirstName]_[LastName]_LLM_Report.pdf`, etc.).
#
# <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExdDZsczFmcjcxeWZjbTA2djh5bDN1bzl5eHJpeHFhdHM0dmczcjkxMyZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/ArrVyXcjSzzxe/giphy.webp" />
